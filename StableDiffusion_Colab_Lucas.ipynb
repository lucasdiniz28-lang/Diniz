# %% [markdown]
# # Stable Diffusion WebUI (AUTOMATIC1111) via Colab
#
# Este notebook foi criado para permitir que você carregue seu próprio modelo `.safetensors` e rode o Stable Diffusion via WebUI no Google Colab, sem depender do Google Drive.

# %%
# Instalação de dependências básicas
# !apt -y update -qq
# !apt -y install -qq aria2 git-lfs wget
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui /content/sd-webui

# %%
# Upload do modelo .safetensors direto do computador
from google.colab import files
uploaded = files.upload()

# %%
# Mover modelo para a pasta correta do WebUI
# !mkdir -p /content/sd-webui/models/Stable-diffusion/
# !mv *.safetensors /content/sd-webui/models/Stable-diffusion/

# %%
# Iniciar o WebUI AUTOMATIC1111
# %cd /content/sd-webui
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle" REQS_FILE="requirements.txt" python launch.py
